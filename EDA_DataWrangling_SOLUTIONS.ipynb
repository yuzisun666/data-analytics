# %% [markdown]
# EDA and Data Wrangling

# %%
# import necessary packages for this module
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot") #ggplot2 is a powerful data visualization package in R

# %%
# read cardio data

data = pd.read_csv("https://raw.githubusercontent.com/robertasgabrys/DSO559/main/sales.csv")

# cardio = pd.read_csv('CardioGoodFitness.csv')

# %% [markdown]
# #### 3.1. Bivariate Distributions
#
# numerical $\times$ categorical variables:
#
# - Boxplots & its variations
# - Barplots
#
#
#
# numerical $\times$ numerical variables:
#
# - Scatterplots
# - Hexbin scatterplots
#
#
#
# categorical $\times$ categorical variables:
#
# - Heatmap

# %% [markdown]
# **3.1.1 Bivariate Distributions: One numerical and one categorical variables**

# %%
cardio.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %% [markdown]
# *- Bivariate Distributions: Box plots and its variations*

# %%
# Interaction: Product x Age

# We can see that the TM195 and TM498 products are used by almost all ages (15-50)
# The TM498 product is used mostly by customers who are in their 20's and early 30's
# The median age of customers who uses all products is arounf 25

sns.boxplot(data = cardio, 
           x = 'Product', 
           y = 'Age')

# %%
# Interaction: Product x Income

# We can see that prodcut TM798 is baught by customer with high income compared to the other two products
# The other two products (TM195 and TM498) are mostly bought by people of lower income (less than 70K with majority less than 55K)


sns.boxplot(data = cardio, 
           x = 'Product', 
           y = 'Income')

# %%
# Interaction: Product x Miles

# It seems that people who expect to walk/run more miles per week are using the product TM798 
# 75% expects to move more than 140 miles per week
# Customers who baught TM195 and TM498 expect to walk/run less per than 140 miles per week


sns.boxplot(data = cardio, 
           x = 'Product', 
           y = 'Miles')

# %%
# Interaction: Fitness x Age

# Customers who rated themselves very low on fitness are in their 20's mostly
# That does not mean that all customers in their 20's rated themselves low


sns.boxplot(data = cardio, 
           x = 'Fitness', 
           y = 'Age')

# %%
# Interaction: Fitness x Income

# Customers with higher income rated themselves highly on fitness (very athlete!)
# Almost all customers who rated themselves 1-4 has lower income (70K and below) 
# Almost 50% of those who gave themselves full score (5) earn above 75K

sns.boxplot(data = cardio, 
           x = 'Fitness', 
           y = 'Income')

# %%
# Interaction: Fitness x Miles

# There is an clear positive corrlation between fitness ratings and the number of miles customers expect to walk/run
# Customers who rated themselves as "athletes" expect to run a lot of miles (more than 75% expect to walk/run more than 150 miles per week)

sns.boxplot(data = cardio, 
           x = 'Fitness', 
           y = 'Miles')

# %% [markdown]
# Notice that I could have done more for the following interactions (please don't leave any variable behind!)
#
# - Age x Gender
# - Income x Gender
# - Miles x Gender
#
#
# - Age x Education
# - Income x Education
# - Miles x Education
#
#
# - Age x MaritalStatus
# - Income x MaritalStatus
# - Miles x MaritalStatus
#
# - Age x Usage
# - Income x Usage
# - Miles x Usage

# %%
# Example on how to use boxplot variations to show interaction between categorical and numerical variable

ax = sns.swarmplot(data = cardio, 
           x = 'Fitness', 
           y = 'Miles')
bottom, top= ax.get_ylim()
# Out:
# 4.050000000000001

# %% [markdown]
# *- Bivariate Distributions: Barplots:*
#
# A bar plot represents an estimate of central tendency for a numeric variable with the height of each rectangle and provides some indication of the uncertainty around that estimate using error bars. The x-axis represents the levels of a given categorical variable, and the y-axis represents the central tendency of a numeric variable.
#
# It is also important to keep in mind that a bar plot shows only the mean (or other estimator) value, but in many cases it may be more informative to show the distribution of values at each level of the categorical variables. In that case, other approaches such as a box or violin plot may be more appropriate.
#
# https://seaborn.pydata.org/generated/seaborn.barplot.html

# %%
# by default, the barplot shows us a 95% confidence interval (ci) for the estimated average for "Income" variable
sns.barplot(data = cardio, 
            x = "Product", 
            y = 'Income')

# %%
# We can get rid of the ci around the mean value as follows

import numpy as np

sns.barplot(data = cardio, 
            x = "Product", 
            y = 'Income', 
            ci = None, 
            estimator = np.median)

# %% [markdown]
# **3.1.2 Bivariate Distributions: One numerical vs. one numerical variables**
#
# - Scatterplots
# - Hexbin scatterplots

# %% [markdown]
# *- Bivariate Distributions: Scatterplots:*
#
#
# https://seaborn.pydata.org/generated/seaborn.scatterplot.html

# %%
# Age x Miles

# Here we don't see a clear relationship between the age of customers and the miles they expect to walk/run per week
# We can see however, that customers among different ages expect to walk/run below 200 miles except for few outlier 
# customers (age btween 25 and 35). These customers expects to walk/run more than 200 miles per week.

sns.scatterplot(data = cardio, 
                x = 'Age', 
                y = 'Miles')

# %%
# Age x Income

# we can see that their is a positive linear trend between Age and Income. As age increases, we tend to see an
# an increase in salary

sns.scatterplot(data = cardio, 
                x = 'Age', 
                y = 'Income')

# %% [markdown]
# *- Bivariate Distributions: Hexbin plots:*
#
# This kind of plot is very useful when we have large dataset, and the points are overlapping with each other when we create a scatter plot
#
# https://seaborn.pydata.org/generated/seaborn.jointplot.html

# %%
# This hexbin plot tells us that there is a linear trend. In addition, it shows us that most of our customers
# are young (20-30 years old), will income on the lower range (30K-50K).

# In addition, the jointplot shows us the marginal distributions of each of the numeric variables

sns.jointplot(data = cardio, 
              x = "Age", 
              y = "Income", 
              kind = 'hex')

# %%
# Other forms of Joint plots

sns.jointplot(data = cardio, 
              x = "Age", 
              y = "Income", 
              kind = 'kde')

# %%
# Other forms of Joint plots

sns.jointplot(data = cardio, 
              x = "Age", 
              y = "Income", 
              kind = 'reg')

# %% [markdown]
# **3.1.3 Bivariate Distributions: One categorical and one categorical variables**

# %% [markdown]
# *- Bivariate Distributions: Heatmap*
#
# The best way to visualize the relationship between two categorical variables is to use a heatmap that shows the crosstabluation among the different levels of the categorical variables.
#
#
# https://seaborn.pydata.org/generated/seaborn.heatmap.html

# %%
# Cross tabulation for two categorical variables

pd.crosstab(cardio['Product'], cardio['MaritalStatus'])
# Out:
# MaritalStatus  Partnered  Single
# Product
# TM195                 48      32
# TM498                 36      24
# TM798                 23      17

# %%
# save the cross tabluation into a variable
# note that the result of running a cross tabulation is saved into a DataFrame data structure (that's how seaborn expects the data)

heatmapData = pd.crosstab(cardio['Product'], cardio['MaritalStatus'])

# %%
type(heatmapData)
# Out:
# pandas.core.frame.DataFrame

# %%
heatmapData
# Out:
# MaritalStatus  Partnered  Single
# Product
# TM195                 48      32
# TM498                 36      24
# TM798                 23      17

# %%
# notice that the default color map might not be intutive. In the previous graph, we see
# that large numerbers are assigned to lighter colors, and small numbers are assigned to darker colors
# we generally tend to think in an oposit way (darker = more , ligher = less)

# so, we can use a different color map. In this case, I am using 'YlGnBu'
# we will cover color in more details later in the semeser, but for not please refer to the following website to 
# select the color map you need for your visualization

# https://matplotlib.org/3.1.1/gallery/color/colormap_reference.html 

sns.heatmap(heatmapData, 
           annot = True)

# %%
ax = sns.heatmap(heatmapData, annot = True)

top, bottom = ax.get_ylim()

ax.set_ylim(top + 0.5, bottom -0.5)
# Out:
# (3.5, -0.5)

# %%
# In the heatmap case, we need to use sequential colors where low numbers are represented with a light color
# and the high number are represented with a darker color 

sns.heatmap(heatmapData, 
           annot = True, 
           cmap = "YlGn")

# %% [markdown]
# #### 5.5 Multivariate Distributions
#
# More than three numerical variables
#
# - Pairplot
# - Correlation heatmap
#
# Two categorical variables and one numerical variable
#
# - Pointplots
# - Boxplot for the numerical variable acoss the different levels in the categorical variable, and use color of the box to represent a the second categorical variable
#
#
# Two numerical and one categorical variables
#
# - Scatterplot for the numerical variables, and use color of the point for one of the categorical variable
# - Scatterplot for the numerical variables, and use size of the point for one of the categorical variable
# - Scatterplot for the numerical variables, and use shape of the point for one of the categorical variable
#
#
# Two numerical and two categorical variables
#
# - Scatterplot for the numerical variables, and use color for one of the categorical variable and size for the other
#
# Any combination of variables
#
# - Facet plots

# %% [markdown]
# **5.5.1 More than three numerical variables**
#
# - Pairplot
# - Correlation heatmap

# %%
# pairplot

sns.pairplot(cardio)

# %%
# correlation heatmap

cardio.corr()
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %%
cor_matrix = cardio.corr()

sns.heatmap(cor_matrix,
            annot = True,
            cmap = 'Reds')

# %% [markdown]
# **5.5.2 Two categorical variables and one numerical variable**
#
# - Pointplots
# - Boxplot for the numerical variable acoss the different levels in the categorical variable, and use color of the box to represent a the second categorical variable

# %%
# pointplots 
# This function also encodes the value of the estimate with height on the other axis, 
# but rather than showing a full bar, it plots the point estimate and confidence interval. 
# Additionally, `pointplot()` connects points from the same hue category. 
# This makes it easy to see how the main relationship is changing as a function of the hue semantic,
# because your eyes are quite good at picking up on differences of slopes:

# https://seaborn.pydata.org/generated/seaborn.pointplot.html

sns.pointplot(data = cardio, 
              x = "Gender", # categorical variable
              y = "Miles", # numerical variable
              hue = "Product", #categorical variable shown in color
              ci = None)

# %%
# boxplots

sns.boxplot(data = cardio, 
              x = "Gender", # categorical variable
              y = "Miles", # numerical variable
              hue = "Product") #categorical variable shown in color

# %% [markdown]
# **5.5.3 Two numerical and one categorical variables**
#
# - Scatterplot for the numerical variables, and use color of the point for one of the categorical variable
# - Scatterplot for the numerical variables, and use size of the point for one of the categorical variable
# - Scatterplot for the numerical variables, and use shape of the point for one of the categorical variable

# %%
# using color 
sns.scatterplot(data = cardio, 
                x = 'Age', 
                y = 'Income', 
                hue = 'Gender')

# %%
# using size 
sns.scatterplot(data = cardio, 
                x = 'Age', 
                y = 'Income', 
                size = 'Gender')

# %% [markdown]
# **5.5.4 Two numerical and two categorical variables**
#
# - Scatterplot for the numerical variables, and use color for one of the categorical variable and size for the other

# %%
# using  color and size  
sns.scatterplot(data = cardio, 
                x = 'Age', 
                y = 'Income', 
                style = 'Gender', 
                hue = 'Product')

# %% [markdown]
# **5.5.5 Any combination of variables (Facet plots)**
#
# - Facet plots

# %%
sns.scatterplot(data = cardio, x = "Income", y = "Miles", hue = "Product")

# %%
g = sns.FacetGrid(cardio, col="Product")
g.map(sns.scatterplot, "Income", "Miles")
#g.add_legend();

# %%
g = sns.FacetGrid(cardio, row="Product", col= "Gender")
g.map(sns.scatterplot, "Income", "Miles")
#g.add_legend();

# %%
g = sns.FacetGrid(cardio, col="Product", hue= "Gender")
g.map(sns.scatterplot, "Income", "Miles")
g.add_legend();

# %% [markdown]
# # Data Wrangling (part 1)

# %% [markdown]
# **Sources:**
#
# - Data Science for Marketing Analytics, by Tommy Blanchard, Debasish Behera, and Pranshu Bhatnagar. Packt Publishing, 2019.
# - https://medium.com/analytics-vidhya/split-apply-combine-strategy-for-data-mining-4fd6e2a0cc99
# - https://www.datacamp.com/community/tutorials/pandas-split-apply-combine-groupby
#
# ### Outline
#
# 1. Reading (and writing) data from different file formats
#
# 1. Data Manipulation
#     - **select** a specific variable or set of variables, a row or a set of rows using indexes.
#     - **filter** rows to obtain a subest of a dataframe based on a given condition
#     - **arrange** the dataframe by index or variable
#     - **group** the data by the levels of a given categorical variable and perform analysis on each group seperately
#     - **mutate** and transform a variable into a new variable
#     - **summarise** and reduce a variable to a summary variable (e.g median).
#
# 2. Data Visualiztion
#
#
# **Learning Objectives**
#
# - Create `pandas` `DataFrame` in `Python`
# - Slice, aggregrate, filter, and sort `pandas` `DataFrames`
# - Apply transformations and functions (built-in and custom) to `DataFrames`
# - Join `DataFrames`, handle missing values, and combine different data sources

# %%
# import necessary packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")

# %% [markdown]
# ## <font color='firebrick'>  1. Importing and Exporting Data
#
# `pandas` provide data scientists with differen methods and APIs (application programming interface) to read data from different sources. The following table shows some of the interfaces:
#
# |**Data Source**|**Read Function**|**Write Function**| **Data Type**|
# |:--------------|:----------------|:-----------------|:-------------|
# csv | `read_csv()` | `to_csv()` | structured
# JSON | `read_json()` | `to_json()` | semi-unstructured
# XML | `read_xml()` | `to_xml()` | semi-structured
# Excel | `read_excel()` | `to_excel()` | structured
# Python Pickle File Format | `read_pickle()` | `to_pickle()` | Python object

# %%
# read the sales.csv data

pd.read_csv("sales.csv")
# Out:
#        Year       Product line      Product type                      Product  \
# 0      2004     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 1      2004     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 2      2005     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 3      2005     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 4      2006     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# ...     ...                ...               ...                          ...
# 17818  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17819  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17820  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17821  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17822  2006  Camping Equipment     Sleeping Bags                   Hibernator
#
#       Order method type Retailer country   Revenue  Planned revenue  \
# 0           Sales visit    United States   5819.70          6586.16
# 1           Sales visit   United Kingdom       NaN              NaN
# 2           Sales visit    United States  10904.28         11363.52
# 3           Sales visit   United Kingdom  27987.84         28855.68
# 4           Sales visit    United States       NaN              NaN
# ...                 ...              ...       ...              ...
# 17818              Mail   United Kingdom       NaN              NaN
# 17819            E-mail    United States       NaN              NaN
# 17820            E-mail   United Kingdom       NaN              NaN
# 17821               Fax    United States       NaN              NaN
# 17822               Fax   United Kingdom       NaN              NaN
#
#        Product cost  Quantity  Unit cost  Unit price  Gross profit  \
# 0            1733.2     619.0        2.8       10.64       4086.50
# 1               NaN       NaN        NaN         NaN           NaN
# 2            2990.4    1068.0        2.8       10.64       7913.88
# 3            7593.6    2712.0        2.8       10.64      20394.24
# 4               NaN       NaN        NaN         NaN           NaN
# ...             ...       ...        ...         ...           ...
# 17818           NaN       NaN        NaN         NaN           NaN
# 17819           NaN       NaN        NaN         NaN           NaN
# 17820           NaN       NaN        NaN         NaN           NaN
# 17821           NaN       NaN        NaN         NaN           NaN
# 17822           NaN       NaN        NaN         NaN           NaN
#
#        Unit sale price
# 0                5.105
# 1                  NaN
# 2               10.210
# 3               10.320
# 4                  NaN
# ...                ...
# 17818              NaN
# 17819              NaN
# 17820              NaN
# 17821              NaN
# 17822              NaN
#
# [17823 rows x 14 columns]

# %%
# add some paramters

# read only the first 4 rows from the data file
pd.read_csv("sales.csv", nrows = 10000)
# Out:
#       Year              Product line          Product type  \
# 0     2004            Golf Equipment      Golf Accessories
# 1     2004            Golf Equipment      Golf Accessories
# 2     2005            Golf Equipment      Golf Accessories
# 3     2005            Golf Equipment      Golf Accessories
# 4     2006            Golf Equipment      Golf Accessories
# ...    ...                       ...                   ...
# 9995  2005  Mountaineering Equipment  Climbing Accessories
# 9996  2005  Mountaineering Equipment  Climbing Accessories
# 9997  2005  Mountaineering Equipment  Climbing Accessories
# 9998  2005  Mountaineering Equipment  Climbing Accessories
# 9999  2005  Mountaineering Equipment  Climbing Accessories
#
#                           Product Order method type Retailer country  \
# 0     Course Pro Golf and Tee Set       Sales visit    United States
# 1     Course Pro Golf and Tee Set       Sales visit   United Kingdom
# 2     Course Pro Golf and Tee Set       Sales visit    United States
# 3     Course Pro Golf and Tee Set       Sales visit   United Kingdom
# 4     Course Pro Golf and Tee Set       Sales visit    United States
# ...                           ...               ...              ...
# 9995            Granite Carabiner       Sales visit          Finland
# 9996            Granite Carabiner       Sales visit          Denmark
# 9997            Granite Carabiner       Sales visit           France
# 9998            Granite Carabiner       Sales visit          Germany
# 9999            Granite Carabiner       Sales visit          Belgium
#
#        Revenue  Planned revenue  Product cost  Quantity  Unit cost  \
# 0      5819.70          6586.16       1733.20     619.0       2.80
# 1          NaN              NaN           NaN       NaN        NaN
# 2     10904.28         11363.52       2990.40    1068.0       2.80
# 3     27987.84         28855.68       7593.60    2712.0       2.80
# 4          NaN              NaN           NaN       NaN        NaN
# ...        ...              ...           ...       ...        ...
# 9995  21764.00         20548.96      10664.36    5441.0       1.96
# 9996  23248.00         22318.08      11391.52    5812.0       1.96
# 9997   4548.00          4411.56       2228.52    1137.0       1.96
# 9998  46760.00         44687.76      22912.40   11690.0       1.96
# 9999  64688.00         61982.84      31697.12   16172.0       1.96
#
#       Unit price  Gross profit  Unit sale price
# 0          10.64       4086.50         5.105000
# 1            NaN           NaN              NaN
# 2          10.64       7913.88        10.210000
# 3          10.64      20394.24        10.320000
# 4            NaN           NaN              NaN
# ...          ...           ...              ...
# 9995        4.00       9884.60         3.780000
# 9996        4.00      10926.56         3.840000
# 9997        4.00       2183.04         3.880000
# 9998        4.00      21775.36         3.826667
# 9999        4.00      30285.72         3.835556
#
# [10000 rows x 14 columns]

# %%
# read only the first 4 rows from the data file

# index is by default numeric starting at 0
# if we have variable in our dataset that has unique values
# such as an Id or date, then can use it as an index

# In the following case, I will use `Product line` as an index when 
# I read my file. Notice that this variable does not have unique values
# for each observation, but I am using it here for the purpose of showing 
# how to use a column from a dataset as an index column

pd.read_csv("sales.csv", nrows = 10000, index_col = "Product line")
# Out:
#                           Year          Product type  \
# Product line
# Golf Equipment            2004      Golf Accessories
# Golf Equipment            2004      Golf Accessories
# Golf Equipment            2005      Golf Accessories
# Golf Equipment            2005      Golf Accessories
# Golf Equipment            2006      Golf Accessories
# ...                        ...                   ...
# Mountaineering Equipment  2005  Climbing Accessories
# Mountaineering Equipment  2005  Climbing Accessories
# Mountaineering Equipment  2005  Climbing Accessories
# Mountaineering Equipment  2005  Climbing Accessories
# Mountaineering Equipment  2005  Climbing Accessories
#
#                                               Product Order method type  \
# Product line
# Golf Equipment            Course Pro Golf and Tee Set       Sales visit
# Golf Equipment            Course Pro Golf and Tee Set       Sales visit
# Golf Equipment            Course Pro Golf and Tee Set       Sales visit
# Golf Equipment            Course Pro Golf and Tee Set       Sales visit
# Golf Equipment            Course Pro Golf and Tee Set       Sales visit
# ...                                               ...               ...
# Mountaineering Equipment            Granite Carabiner       Sales visit
# Mountaineering Equipment            Granite Carabiner       Sales visit
# Mountaineering Equipment            Granite Carabiner       Sales visit
# Mountaineering Equipment            Granite Carabiner       Sales visit
# Mountaineering Equipment            Granite Carabiner       Sales visit
#
#                          Retailer country   Revenue  Planned revenue  \
# Product line
# Golf Equipment              United States   5819.70          6586.16
# Golf Equipment             United Kingdom       NaN              NaN
# Golf Equipment              United States  10904.28         11363.52
# Golf Equipment             United Kingdom  27987.84         28855.68
# Golf Equipment              United States       NaN              NaN
# ...                                   ...       ...              ...
# Mountaineering Equipment          Finland  21764.00         20548.96
# Mountaineering Equipment          Denmark  23248.00         22318.08
# Mountaineering Equipment           France   4548.00          4411.56
# Mountaineering Equipment          Germany  46760.00         44687.76
# Mountaineering Equipment          Belgium  64688.00         61982.84
#
#                           Product cost  Quantity  Unit cost  Unit price  \
# Product line
# Golf Equipment                 1733.20     619.0       2.80       10.64
# Golf Equipment                     NaN       NaN        NaN         NaN
# Golf Equipment                 2990.40    1068.0       2.80       10.64
# Golf Equipment                 7593.60    2712.0       2.80       10.64
# Golf Equipment                     NaN       NaN        NaN         NaN
# ...                                ...       ...        ...         ...
# Mountaineering Equipment      10664.36    5441.0       1.96        4.00
# Mountaineering Equipment      11391.52    5812.0       1.96        4.00
# Mountaineering Equipment       2228.52    1137.0       1.96        4.00
# Mountaineering Equipment      22912.40   11690.0       1.96        4.00
# Mountaineering Equipment      31697.12   16172.0       1.96        4.00
#
#                           Gross profit  Unit sale price
# Product line
# Golf Equipment                 4086.50         5.105000
# Golf Equipment                     NaN              NaN
# Golf Equipment                 7913.88        10.210000
# Golf Equipment                20394.24        10.320000
# Golf Equipment                     NaN              NaN
# ...                                ...              ...
# Mountaineering Equipment       9884.60         3.780000
# Mountaineering Equipment      10926.56         3.840000
# Mountaineering Equipment       2183.04         3.880000
# Mountaineering Equipment      21775.36         3.826667
# Mountaineering Equipment      30285.72         3.835556
#
# [10000 rows x 13 columns]

# %%
# we can also request to read only specific columns from the data file
# in this example, we will read only three columns from the 
# file (year, product line, and product type)

mydata = pd.read_csv("sales.csv", nrows = 10000, usecols = ['Product', 'Revenue', 'Planned revenue'])
mydata.head()
# Out:
#                        Product   Revenue  Planned revenue
# 0  Course Pro Golf and Tee Set   5819.70          6586.16
# 1  Course Pro Golf and Tee Set       NaN              NaN
# 2  Course Pro Golf and Tee Set  10904.28         11363.52
# 3  Course Pro Golf and Tee Set  27987.84         28855.68
# 4  Course Pro Golf and Tee Set       NaN              NaN

# %% [markdown]
# ### <font color='blue'>  DIY-1: Read JSON Files </font>
#
#
# 1. Watch this 1-min YouTube video that describes the structure of JSON files quickly (https://www.youtube.com/watch?v=7mj-p1Os6QA).
#
# 2. Read the `user_info.json` file into Python, and save the data in a variable called `mydata`.
#
# 3. What is the type of the variable `mydata`?
#
# 4. Print the first 3 observations from the variable `mydata`.

# %%
# read_json return a pandas DataFrame object. 
# we can use the head() method for DataFrame to find the first three obs.

mydata = pd.read_json("user_info.json")

# %%
type(mydata)
# Out:
# pandas.core.frame.DataFrame

# %%
mydata.head()
# Out:
#                         _id  index                                  guid  \
# 0  5c0a28d7a647437fd3d3a6aa      0  832f1af4-fb18-4ba8-b032-f4cbf343dbe9
# 1  5c0a28d780f6278b11586ab1      1  4306cb37-9506-48c2-8ccf-e69a063589ee
# 2  5c0a28d722e2e29d9bce2b64      2  5019e436-7cc4-48ee-a384-3483131f8ee1
# 3  5c0a28d76b5e8859a754cb4f      3  d2c4b1eb-2974-463a-b288-d1dae5dec187
# 4  5c0a28d7ebb99c08e2288c76      4  df0b59ed-2e81-43f1-9ae0-16f138e738be
#
#    isActive    balance                    picture  age eyeColor  \
# 0     False  $3,806.93  http://placehold.it/32x32   20    green
# 1      True  $3,330.01  http://placehold.it/32x32   22    brown
# 2      True  $1,619.46  http://placehold.it/32x32   40    green
# 3     False  $3,334.12  http://placehold.it/32x32   29     blue
# 4     False  $1,368.48  http://placehold.it/32x32   33    brown
#
#                  name  gender  ...              phone  \
# 0         Grace Berry  female  ...  +1 (814) 555-3298
# 1      Hilary Sellers  female  ...  +1 (942) 536-3059
# 2      Sherri Gilbert  female  ...  +1 (954) 591-2183
# 3  Caldwell Patterson    male  ...  +1 (815) 400-3780
# 4      Head Mcconnell    male  ...  +1 (820) 573-3154
#
#                                              address  \
# 0        698 Kansas Place, Bethpage, Louisiana, 7695
# 1      309 Kingsway Place, Kilbourne, New York, 3771
# 2            347 Seeley Street, Witmer, Kansas, 9369
# 3          178 Stewart Street, Ferney, Wyoming, 9118
# 4  189 Rogers Avenue, Lindisfarne, Mississippi, 1961
#
#                                                about  \
# 0  Nostrud consectetur elit occaecat dolore incid...
# 1  Sunt id ipsum velit voluptate. Ullamco non non...
# 2  Laborum ad excepteur amet sunt aliqua veniam c...
# 3  Eu amet aliqua magna ipsum quis et ut reprehen...
# 4  Sunt amet exercitation aliqua cillum commodo o...
#
#                     registered   latitude   longitude  \
# 0  2015-12-09T08:21:48 -06:-30 -65.630631  131.991768
# 1  2014-12-15T11:42:39 -06:-30  38.790260   48.442002
# 2  2014-10-31T05:02:03 -06:-30  34.404508 -116.452211
# 3  2018-04-02T03:06:31 -06:-30 -63.424959  -51.151783
# 4  2016-01-06T09:38:15 -06:-30 -80.136744  176.780600
#
#                                                 tags  \
# 0  [eu, id, fugiat, deserunt, nulla, proident, la...
# 1  [deserunt, do, adipisicing, in, aliqua, duis, ...
# 2  [adipisicing, cillum, deserunt, aute, ipsum, c...
# 3  [adipisicing, veniam, dolor, duis, aute, tempo...
# 4  [qui, aute, voluptate, eiusmod, est, est, cupi...
#
#                                              friends  \
# 0  [{'id': 0, 'name': 'Small Pena'}, {'id': 1, 'n...
# 1  [{'id': 0, 'name': 'Spears Smith'}, {'id': 1, ...
# 2  [{'id': 0, 'name': 'Sexton Watts'}, {'id': 1, ...
# 3  [{'id': 0, 'name': 'Anne Holcomb'}, {'id': 1, ...
# 4  [{'id': 0, 'name': 'Elnora Peck'}, {'id': 1, '...
#
#                                             greeting favoriteFruit
# 0    Hello, Grace Berry! You have 1 unread messages.    strawberry
# 1  Hello, Hilary Sellers! You have 4 unread messa...         apple
# 2  Hello, Sherri Gilbert! You have 1 unread messa...         apple
# 3  Hello, Caldwell Patterson! You have 6 unread m...    strawberry
# 4  Hello, Head Mcconnell! You have 5 unread messa...    strawberry
#
# [5 rows x 22 columns]

# %%
mydata['tags']
# Out:
# 0    [eu, id, fugiat, deserunt, nulla, proident, la...
# 1    [deserunt, do, adipisicing, in, aliqua, duis, ...
# 2    [adipisicing, cillum, deserunt, aute, ipsum, c...
# 3    [adipisicing, veniam, dolor, duis, aute, tempo...
# 4    [qui, aute, voluptate, eiusmod, est, est, cupi...
# 5    [dolore, eiusmod, laborum, dolore, aliquip, al...
# Name: tags, dtype: object

# %% [markdown]
# ## <font color='firebrick'> 2. Selecting Data

# %%
# read the sales.csv dataset and save in a variable called sales

sales = pd.read_csv("sales.csv")
sales.head()
# Out:
#    Year    Product line      Product type                      Product  \
# 0  2004  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 1  2004  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 2  2005  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 3  2005  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 4  2006  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
#
#   Order method type Retailer country   Revenue  Planned revenue  Product cost  \
# 0       Sales visit    United States   5819.70          6586.16        1733.2
# 1       Sales visit   United Kingdom       NaN              NaN           NaN
# 2       Sales visit    United States  10904.28         11363.52        2990.4
# 3       Sales visit   United Kingdom  27987.84         28855.68        7593.6
# 4       Sales visit    United States       NaN              NaN           NaN
#
#    Quantity  Unit cost  Unit price  Gross profit  Unit sale price
# 0     619.0        2.8       10.64       4086.50            5.105
# 1       NaN        NaN         NaN           NaN              NaN
# 2    1068.0        2.8       10.64       7913.88           10.210
# 3    2712.0        2.8       10.64      20394.24           10.320
# 4       NaN        NaN         NaN           NaN              NaN

# %% [markdown]
# |**Operation**|**Syntax**|**Result**|
# |:--------------|:----------------|:-----------------|
# Select a column | `df['colname']` | Series
# Select multiple columns | `df[['colname1', 'colname2', ...]]` | DataFrame
# Select a row by integer index location | `df.iloc[index_location]` | Series
# Slice rows |`df.iloc[start_index:end_index+1]`| DataFrame
# Select multiple columns by index location |`df.iloc[,start_index:end_index+1]`| DataFrame
# Slice rows and select multiple columns by index location | `df.iloc[start_index:end_index+1, start_index:end_index+1]`| DataFrame

# %% [markdown]
# #### 2.1 Selecting a column

# %%
# Selecting a column

# What is the total revenue for all years?
sales['Revenue'].sum()


# could be written as
# sales['Revenue'].sum()
# Out:
# 627745954.4599999

# %%
type(sales['Revenue']) # returns a series object
# Out:
# pandas.core.series.Series

# %%
type(sales[['Revenue']]) # returns a dataframe
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### 2.2 Selecting multiple columns using column names

# %%
# Selecting multiple columns 

# Create a mini dataframe that has the values for the 
# Product, Revenue, and Planned revenue

type(sales[['Product', 'Revenue', 'Planned revenue']])
# Out:
# pandas.core.frame.DataFrame

# %%
## What is the total revenue and planned revenue for all sales?

sales[['Revenue', 'Planned revenue']].sum()
# Out:
# Revenue            6.277460e+08
# Planned revenue    6.401190e+08
# dtype: float64

# %%
## What is the max revenue and max planned revenue across all sales?

sales[['Revenue', 'Planned revenue']].max()
# Out:
# Revenue            3644349.30
# Planned revenue    3477909.78
# dtype: float64

# %% [markdown]
# #### 2.3 Selecting a row by index location

# %%
# List all the information about the 3rd sale in the dataset
# i.e. select the 3rd row or observation

# the index starts at 0, so the third observation has index = 2

sales.iloc[2]
# Out:
# Year                                        2005
# Product line                      Golf Equipment
# Product type                    Golf Accessories
# Product              Course Pro Golf and Tee Set
# Order method type                    Sales visit
# Retailer country                   United States
# Revenue                                  10904.3
# Planned revenue                          11363.5
# Product cost                              2990.4
# Quantity                                    1068
# Unit cost                                    2.8
# Unit price                                 10.64
# Gross profit                             7913.88
# Unit sale price                            10.21
# Name: 2, dtype: object

# %%
# select obs number 1000
sales.iloc[999]
# Out:
# Year                                2005
# Product line              Golf Equipment
# Product type            Golf Accessories
# Product              Course Pro Golf Bag
# Order method type            Sales visit
# Retailer country                  Brazil
# Revenue                              NaN
# Planned revenue                      NaN
# Product cost                         NaN
# Quantity                             NaN
# Unit cost                            NaN
# Unit price                           NaN
# Gross profit                         NaN
# Unit sale price                      NaN
# Name: 999, dtype: object

# %% [markdown]
# #### 2.4 Slicing a subset of the dataset

# %%
sales.head(10)
# Out:
#    Year    Product line      Product type                      Product  \
# 0  2004  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 1  2004  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 2  2005  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 3  2005  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 4  2006  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 5  2006  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 6  2004  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 7  2004  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 8  2004  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 9  2004  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
#
#   Order method type Retailer country   Revenue  Planned revenue  Product cost  \
# 0       Sales visit    United States   5819.70          6586.16        1733.2
# 1       Sales visit   United Kingdom       NaN              NaN           NaN
# 2       Sales visit    United States  10904.28         11363.52        2990.4
# 3       Sales visit   United Kingdom  27987.84         28855.68        7593.6
# 4       Sales visit    United States       NaN              NaN           NaN
# 5       Sales visit   United Kingdom   8750.77          8926.96        2349.2
# 6       Sales visit           Canada       NaN              NaN           NaN
# 7       Sales visit           Mexico  13497.62         14598.08        3841.6
# 8       Sales visit           Brazil       NaN              NaN           NaN
# 9       Sales visit            Japan       NaN              NaN           NaN
#
#    Quantity  Unit cost  Unit price  Gross profit  Unit sale price
# 0     619.0        2.8       10.64       4086.50         5.105000
# 1       NaN        NaN         NaN           NaN              NaN
# 2    1068.0        2.8       10.64       7913.88        10.210000
# 3    2712.0        2.8       10.64      20394.24        10.320000
# 4       NaN        NaN         NaN           NaN              NaN
# 5     839.0        2.8       10.64       6401.57        10.430000
# 6       NaN        NaN         NaN           NaN              NaN
# 7    1372.0        2.8       10.64       9656.02         6.806667
# 8       NaN        NaN         NaN           NaN              NaN
# 9       NaN        NaN         NaN           NaN              NaN

# %%
# List all the information about the first 10 elements

# df.iloc[start_index:end_index+1]

sales.iloc[0:10]
# or sales.head(10)
# Out:
#    Year    Product line      Product type                      Product  \
# 0  2004  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 1  2004  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 2  2005  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 3  2005  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 4  2006  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 5  2006  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 6  2004  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 7  2004  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 8  2004  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 9  2004  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
#
#   Order method type Retailer country   Revenue  Planned revenue  Product cost  \
# 0       Sales visit    United States   5819.70          6586.16        1733.2
# 1       Sales visit   United Kingdom       NaN              NaN           NaN
# 2       Sales visit    United States  10904.28         11363.52        2990.4
# 3       Sales visit   United Kingdom  27987.84         28855.68        7593.6
# 4       Sales visit    United States       NaN              NaN           NaN
# 5       Sales visit   United Kingdom   8750.77          8926.96        2349.2
# 6       Sales visit           Canada       NaN              NaN           NaN
# 7       Sales visit           Mexico  13497.62         14598.08        3841.6
# 8       Sales visit           Brazil       NaN              NaN           NaN
# 9       Sales visit            Japan       NaN              NaN           NaN
#
#    Quantity  Unit cost  Unit price  Gross profit  Unit sale price
# 0     619.0        2.8       10.64       4086.50         5.105000
# 1       NaN        NaN         NaN           NaN              NaN
# 2    1068.0        2.8       10.64       7913.88        10.210000
# 3    2712.0        2.8       10.64      20394.24        10.320000
# 4       NaN        NaN         NaN           NaN              NaN
# 5     839.0        2.8       10.64       6401.57        10.430000
# 6       NaN        NaN         NaN           NaN              NaN
# 7    1372.0        2.8       10.64       9656.02         6.806667
# 8       NaN        NaN         NaN           NaN              NaN
# 9       NaN        NaN         NaN           NaN              NaN

# %%
# List all the information about the all elements starting with the third
# observation, until (and including) the 10th observation

sales.iloc[2:10]
# Out:
#    Year    Product line      Product type                      Product  \
# 2  2005  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 3  2005  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 4  2006  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 5  2006  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 6  2004  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 7  2004  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 8  2004  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 9  2004  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
#
#   Order method type Retailer country   Revenue  Planned revenue  Product cost  \
# 2       Sales visit    United States  10904.28         11363.52        2990.4
# 3       Sales visit   United Kingdom  27987.84         28855.68        7593.6
# 4       Sales visit    United States       NaN              NaN           NaN
# 5       Sales visit   United Kingdom   8750.77          8926.96        2349.2
# 6       Sales visit           Canada       NaN              NaN           NaN
# 7       Sales visit           Mexico  13497.62         14598.08        3841.6
# 8       Sales visit           Brazil       NaN              NaN           NaN
# 9       Sales visit            Japan       NaN              NaN           NaN
#
#    Quantity  Unit cost  Unit price  Gross profit  Unit sale price
# 2    1068.0        2.8       10.64       7913.88        10.210000
# 3    2712.0        2.8       10.64      20394.24        10.320000
# 4       NaN        NaN         NaN           NaN              NaN
# 5     839.0        2.8       10.64       6401.57        10.430000
# 6       NaN        NaN         NaN           NaN              NaN
# 7    1372.0        2.8       10.64       9656.02         6.806667
# 8       NaN        NaN         NaN           NaN              NaN
# 9       NaN        NaN         NaN           NaN              NaN

# %%
# List all the information about the all elements starting with the third
# observation, until the last observation

#sales.iloc[2:17823]
sales.iloc[2:]
# Out:
#        Year       Product line      Product type                      Product  \
# 2      2005     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 3      2005     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 4      2006     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 5      2006     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 6      2004     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# ...     ...                ...               ...                          ...
# 17818  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17819  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17820  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17821  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17822  2006  Camping Equipment     Sleeping Bags                   Hibernator
#
#       Order method type Retailer country   Revenue  Planned revenue  \
# 2           Sales visit    United States  10904.28         11363.52
# 3           Sales visit   United Kingdom  27987.84         28855.68
# 4           Sales visit    United States       NaN              NaN
# 5           Sales visit   United Kingdom   8750.77          8926.96
# 6           Sales visit           Canada       NaN              NaN
# ...                 ...              ...       ...              ...
# 17818              Mail   United Kingdom       NaN              NaN
# 17819            E-mail    United States       NaN              NaN
# 17820            E-mail   United Kingdom       NaN              NaN
# 17821               Fax    United States       NaN              NaN
# 17822               Fax   United Kingdom       NaN              NaN
#
#        Product cost  Quantity  Unit cost  Unit price  Gross profit  \
# 2            2990.4    1068.0        2.8       10.64       7913.88
# 3            7593.6    2712.0        2.8       10.64      20394.24
# 4               NaN       NaN        NaN         NaN           NaN
# 5            2349.2     839.0        2.8       10.64       6401.57
# 6               NaN       NaN        NaN         NaN           NaN
# ...             ...       ...        ...         ...           ...
# 17818           NaN       NaN        NaN         NaN           NaN
# 17819           NaN       NaN        NaN         NaN           NaN
# 17820           NaN       NaN        NaN         NaN           NaN
# 17821           NaN       NaN        NaN         NaN           NaN
# 17822           NaN       NaN        NaN         NaN           NaN
#
#        Unit sale price
# 2                10.21
# 3                10.32
# 4                  NaN
# 5                10.43
# 6                  NaN
# ...                ...
# 17818              NaN
# 17819              NaN
# 17820              NaN
# 17821              NaN
# 17822              NaN
#
# [17821 rows x 14 columns]

# %%
# OR

len(sales)

sales.iloc[2:len(sales)]
sales.iloc[2:sales.shape[0]]
# Out:
#        Year       Product line      Product type                      Product  \
# 2      2005     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 3      2005     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 4      2006     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 5      2006     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 6      2004     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# ...     ...                ...               ...                          ...
# 17818  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17819  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17820  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17821  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17822  2006  Camping Equipment     Sleeping Bags                   Hibernator
#
#       Order method type Retailer country   Revenue  Planned revenue  \
# 2           Sales visit    United States  10904.28         11363.52
# 3           Sales visit   United Kingdom  27987.84         28855.68
# 4           Sales visit    United States       NaN              NaN
# 5           Sales visit   United Kingdom   8750.77          8926.96
# 6           Sales visit           Canada       NaN              NaN
# ...                 ...              ...       ...              ...
# 17818              Mail   United Kingdom       NaN              NaN
# 17819            E-mail    United States       NaN              NaN
# 17820            E-mail   United Kingdom       NaN              NaN
# 17821               Fax    United States       NaN              NaN
# 17822               Fax   United Kingdom       NaN              NaN
#
#        Product cost  Quantity  Unit cost  Unit price  Gross profit  \
# 2            2990.4    1068.0        2.8       10.64       7913.88
# 3            7593.6    2712.0        2.8       10.64      20394.24
# 4               NaN       NaN        NaN         NaN           NaN
# 5            2349.2     839.0        2.8       10.64       6401.57
# 6               NaN       NaN        NaN         NaN           NaN
# ...             ...       ...        ...         ...           ...
# 17818           NaN       NaN        NaN         NaN           NaN
# 17819           NaN       NaN        NaN         NaN           NaN
# 17820           NaN       NaN        NaN         NaN           NaN
# 17821           NaN       NaN        NaN         NaN           NaN
# 17822           NaN       NaN        NaN         NaN           NaN
#
#        Unit sale price
# 2                10.21
# 3                10.32
# 4                  NaN
# 5                10.43
# 6                  NaN
# ...                ...
# 17818              NaN
# 17819              NaN
# 17820              NaN
# 17821              NaN
# 17822              NaN
#
# [17821 rows x 14 columns]

# %% [markdown]
# #### 2.5 Select multiple columns using indexes of columns

# %%
# Using indexing techniques, create a mini dataframe that has 
# the values for the Product, Revenue, and Planned revenue

#sales[['Product', 'Revenue', 'Planned revenue']]

# df[ROWs, COLUMNS]
sales.iloc[:,[3,6,7]]
# OR
#sales.iloc[[3, 6,7]]
# Out:
#                            Product   Revenue  Planned revenue
# 2      Course Pro Golf and Tee Set  10904.28         11363.52
# 3      Course Pro Golf and Tee Set  27987.84         28855.68
# 4      Course Pro Golf and Tee Set       NaN              NaN
# 5      Course Pro Golf and Tee Set   8750.77          8926.96
# 6      Course Pro Golf and Tee Set       NaN              NaN
# ...                            ...       ...              ...
# 17818                   Hibernator       NaN              NaN
# 17819                   Hibernator       NaN              NaN
# 17820                   Hibernator       NaN              NaN
# 17821                   Hibernator       NaN              NaN
# 17822                   Hibernator       NaN              NaN
#
# [17821 rows x 3 columns]

# %%
# Using indexing techniques, create a mini dataframe that has 
# the values for the first 4 columns


# OR 
# sales.iloc[:,:4]

# %% [markdown]
# ### <font color='blue'>  DIY-2: Slicing and dicing datasets </font>
#
# Create a mini dataset (1st half of the original dataset) that contains the columns Year, Product, Revenue, and Planned Revenue.

# %%
sales = pd.read_csv('sales.csv')

# %%
int(len(sales)/2)
# Out:
# 8911

# %%
# OR we can only use indexes

#sales.iloc[0:int(len(sales)/2),[0, 3,6,7]]

sales.loc[:,['Year', 'Product', 'Revenue', 'Planned revenue']].head(int(len(sales)/2))
# Out:
#       Year                      Product   Revenue  Planned revenue
# 0     2004  Course Pro Golf and Tee Set   5819.70          6586.16
# 1     2004  Course Pro Golf and Tee Set       NaN              NaN
# 2     2005  Course Pro Golf and Tee Set  10904.28         11363.52
# 3     2005  Course Pro Golf and Tee Set  27987.84         28855.68
# 4     2006  Course Pro Golf and Tee Set       NaN              NaN
# ...    ...                          ...       ...              ...
# 8906  2007        TrailChef Kitchen Kit       NaN              NaN
# 8907  2007        TrailChef Kitchen Kit       NaN              NaN
# 8908  2007        TrailChef Kitchen Kit       NaN              NaN
# 8909  2007        TrailChef Kitchen Kit       NaN              NaN
# 8910  2007        TrailChef Kitchen Kit       NaN              NaN
#
# [8911 rows x 4 columns]

# %% [markdown]
# ## <font color='firebrick'> 3. Filtering Data based on a Condition
#
# So far, we have being selecting specific variables on observations based on their indicies.
#
# In many cases, we want to select a subset of our observations based on a specific conidition. e.g. Suppose we want to find the products who have sold more than 1000 per sale.

# %% [markdown]
# ### Filtering with One Condition

# %%
# List all obeservations with quantity sold greater than or equal to 1000.

sales.loc[sales['Quantity'] >=1000,['Product', 'Quantity']]
# Out:
#                            Product  Quantity
# 2      Course Pro Golf and Tee Set    1068.0
# 3      Course Pro Golf and Tee Set    2712.0
# 7      Course Pro Golf and Tee Set    1372.0
# 16     Course Pro Golf and Tee Set    2152.0
# 18     Course Pro Golf and Tee Set    2101.0
# ...                            ...       ...
# 17801                   Hibernator   11845.0
# 17802                   Hibernator    6352.0
# 17805                   Hibernator    1334.0
# 17813                   Hibernator   20311.0
# 17814                   Hibernator    8352.0
#
# [3748 rows x 2 columns]

# %%
sales.head(3)
# Out:
#    Year    Product line      Product type                      Product  \
# 0  2004  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 1  2004  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 2  2005  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
#
#   Order method type Retailer country   Revenue  Planned revenue  Product cost  \
# 0       Sales visit    United States   5819.70          6586.16        1733.2
# 1       Sales visit   United Kingdom       NaN              NaN           NaN
# 2       Sales visit    United States  10904.28         11363.52        2990.4
#
#    Quantity  Unit cost  Unit price  Gross profit  Unit sale price
# 0     619.0        2.8       10.64       4086.50            5.105
# 1       NaN        NaN         NaN           NaN              NaN
# 2    1068.0        2.8       10.64       7913.88           10.210

# %%
# List all observations that resulted in revenue less than the planned revenue?

sales.loc[sales['Revenue'] < sales['Planned revenue'] ,]
# Out:
#        Year       Product line      Product type                      Product  \
# 0      2004     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 2      2005     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 3      2005     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 5      2006     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 7      2004     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# ...     ...                ...               ...                          ...
# 17805  2005  Camping Equipment     Sleeping Bags                   Hibernator
# 17809  2005  Camping Equipment     Sleeping Bags                   Hibernator
# 17811  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17813  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17814  2006  Camping Equipment     Sleeping Bags                   Hibernator
#
#       Order method type Retailer country     Revenue  Planned revenue  \
# 0           Sales visit    United States     5819.70          6586.16
# 2           Sales visit    United States    10904.28         11363.52
# 3           Sales visit   United Kingdom    27987.84         28855.68
# 5           Sales visit   United Kingdom     8750.77          8926.96
# 7           Sales visit           Mexico    13497.62         14598.08
# ...                 ...              ...         ...              ...
# 17805              Mail    United States   184118.68        195871.22
# 17809               Fax    United States    72598.52         77232.58
# 17811         Telephone    United States    70860.92         74589.64
# 17813               Web    United States  2858284.19       2982264.13
# 17814               Web   United Kingdom  1175927.72       1226324.16
#
#        Product cost  Quantity  Unit cost  Unit price  Gross profit  \
# 0            1733.2     619.0        2.8       10.64       4086.50
# 2            2990.4    1068.0        2.8       10.64       7913.88
# 3            7593.6    2712.0        2.8       10.64      20394.24
# 5            2349.2     839.0        2.8       10.64       6401.57
# 7            3841.6    1372.0        2.8       10.64       9656.02
# ...             ...       ...        ...         ...           ...
# 17805      114724.0    1334.0       86.0      146.83      69394.68
# 17809       45236.0     526.0       86.0      146.83      27362.52
# 17811       43688.0     508.0       86.0      146.83      27172.92
# 17813     1746746.0   20311.0       86.0      146.83    1111538.19
# 17814      718272.0    8352.0       86.0      146.83     457655.72
#
#        Unit sale price
# 0             5.105000
# 2            10.210000
# 3            10.320000
# 5            10.430000
# 7             6.806667
# ...                ...
# 17805       138.020000
# 17809       138.020000
# 17811       139.490000
# 17813       140.866250
# 17814       140.849259
#
# [3236 rows x 14 columns]

# %%
# List all product names who's revenue exceeded planned revenue
sales.loc[sales['Revenue'] > sales['Planned revenue'], ['Product']].drop_duplicates()
# Out:
#                             Product
# 3903            TrailChef Water Bag
# 4018          TrailChef Kitchen Kit
# 4132             TrailChef Cook Set
# 4246         TrailChef Single Flame
# 4362         TrailChef Double Flame
# 4473            Hibernator Camp Cot
# 4588          BugShield Lotion Lite
# 4701             Compact Relief Kit
# 4818             Insect Bite Relief
# 4930            Course Pro Umbrella
# 5044              Course Pro Gloves
# 6758          Firefly Climbing Lamp
# 6872   Firefly Rechargeable Battery
# 6986              Granite Chalk Bag
# 9378              TrailChef Canteen
# 9397                  TrailChef Cup
# 9416               TrailChef Kettle
# 9435             TrailChef Utensils
# 9454                Hibernator Lite
# 9473             Hibernator Extreme
# 9492                 Hibernator Pad
# 9511              Hibernator Pillow
# 9529              BugShield Natural
# 9549                BugShield Spray
# 9568               BugShield Lotion
# 9586              BugShield Extreme
# 9985              Granite Carabiner
# 10004                 Granite Belay
# 10023                Granite Pulley
# 10042               Firefly Charger
# 10309                   Aloe Relief
# 10623               Calamine Relief

# %%
# What is the highest revenue genderated through Web sales?

sales.loc[sales['Order method type'] == "Web",['Revenue']].max()
# Out:
# Revenue    3644349.3
# dtype: float64

# %%
sales.head(3)
# Out:
#    Year    Product line      Product type                      Product  \
# 0  2004  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 1  2004  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 2  2005  Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
#
#   Order method type Retailer country   Revenue  Planned revenue  Product cost  \
# 0       Sales visit    United States   5819.70          6586.16        1733.2
# 1       Sales visit   United Kingdom       NaN              NaN           NaN
# 2       Sales visit    United States  10904.28         11363.52        2990.4
#
#    Quantity  Unit cost  Unit price  Gross profit  Unit sale price
# 0     619.0        2.8       10.64       4086.50            5.105
# 1       NaN        NaN         NaN           NaN              NaN
# 2    1068.0        2.8       10.64       7913.88           10.210

# %%
sales['Order method type'].unique()
# Out:
# array(['Sales visit', 'Telephone', 'Web', 'Special', 'Mail', 'E-mail',
#        'Fax'], dtype=object)

# %% [markdown]
# ### Filtering with Multiple Conditions

# %%
# List all the sales for the 'BugShield Extreme' product that was sold in the United States

sales.loc[(sales['Product'] == 'BugShield Extreme') & (sales['Retailer country'] == "United States"),]
# Out:
#        Year        Product line       Product type            Product  \
# 9283   2004  Outdoor Protection  Insect Repellents  BugShield Extreme
# 9319   2005  Outdoor Protection  Insect Repellents  BugShield Extreme
# 9355   2006  Outdoor Protection  Insect Repellents  BugShield Extreme
# 10611  2004  Outdoor Protection  Insect Repellents  BugShield Extreme
# 10613  2004  Outdoor Protection  Insect Repellents  BugShield Extreme
# 10615  2004  Outdoor Protection  Insect Repellents  BugShield Extreme
# 10617  2004  Outdoor Protection  Insect Repellents  BugShield Extreme
# 10619  2004  Outdoor Protection  Insect Repellents  BugShield Extreme
# 10621  2004  Outdoor Protection  Insect Repellents  BugShield Extreme
# 10827  2005  Outdoor Protection  Insect Repellents  BugShield Extreme
# 10829  2005  Outdoor Protection  Insect Repellents  BugShield Extreme
# 10831  2005  Outdoor Protection  Insect Repellents  BugShield Extreme
# 10833  2005  Outdoor Protection  Insect Repellents  BugShield Extreme
# 10835  2005  Outdoor Protection  Insect Repellents  BugShield Extreme
# 10837  2005  Outdoor Protection  Insect Repellents  BugShield Extreme
# 11043  2006  Outdoor Protection  Insect Repellents  BugShield Extreme
# 11045  2006  Outdoor Protection  Insect Repellents  BugShield Extreme
# 11047  2006  Outdoor Protection  Insect Repellents  BugShield Extreme
# 11049  2006  Outdoor Protection  Insect Repellents  BugShield Extreme
# 11051  2006  Outdoor Protection  Insect Repellents  BugShield Extreme
# 11053  2006  Outdoor Protection  Insect Repellents  BugShield Extreme
#
#       Order method type Retailer country    Revenue  Planned revenue  \
# 9283        Sales visit    United States  387494.73        416661.00
# 9319        Sales visit    United States  119176.05        126014.00
# 9355        Sales visit    United States   19881.19         20685.00
# 10611         Telephone    United States  192626.00        179142.18
# 10613               Web    United States  747229.00        694922.97
# 10615           Special    United States        NaN              NaN
# 10617              Mail    United States  291298.00        270907.14
# 10619            E-mail    United States   43974.00         40895.82
# 10621               Fax    United States   55510.00         51624.30
# 10827         Telephone    United States  104272.00         98015.68
# 10829               Web    United States  592165.00        559037.99
# 10831           Special    United States   26187.00         24615.78
# 10833              Mail    United States   52290.00         49152.60
# 10835            E-mail    United States        NaN              NaN
# 10837               Fax    United States   51653.00         48553.82
# 11043         Telephone    United States   47131.00         46023.74
# 11045               Web    United States  360087.00        340810.05
# 11047           Special    United States        NaN              NaN
# 11049              Mail    United States        NaN              NaN
# 11051            E-mail    United States        NaN              NaN
# 11053               Fax    United States    7357.00          7357.00
#
#        Product cost  Quantity  Unit cost  Unit price  Gross profit  \
# 9283      144045.66   59523.0       2.42         7.0     243449.07
# 9319       43564.84   18002.0       2.42         7.0      75611.21
# 9355        7151.10    2955.0       2.42         7.0      12730.09
# 10611      66593.56   27518.0       2.42         7.0     112548.62
# 10613     258327.74  106747.0       2.42         7.0     436595.23
# 10615           NaN       NaN        NaN         NaN           NaN
# 10617     100705.88   41614.0       2.42         7.0     170201.26
# 10619      15202.44    6282.0       2.42         7.0      25693.38
# 10621      19190.60    7930.0       2.42         7.0      32433.70
# 10827      36048.32   14896.0       2.42         7.0      61967.36
# 10829     204719.90   84595.0       2.42         7.0     354318.09
# 10831       9053.22    3741.0       2.42         7.0      15562.56
# 10833      18077.40    7470.0       2.42         7.0      31075.20
# 10835           NaN       NaN        NaN         NaN           NaN
# 10837      17857.18    7379.0       2.42         7.0      30696.64
# 11043      16293.86    6733.0       2.42         7.0      29729.88
# 11045     124487.22   51441.0       2.42         7.0     216322.83
# 11047           NaN       NaN        NaN         NaN           NaN
# 11049           NaN       NaN        NaN         NaN           NaN
# 11051           NaN       NaN        NaN         NaN           NaN
# 11053       2543.42    1051.0       2.42         7.0       4813.58
#
#        Unit sale price
# 9283          6.510000
# 9319          6.650000
# 9355          6.720000
# 10611         6.510000
# 10613         6.510000
# 10615              NaN
# 10617         6.510000
# 10619         6.510000
# 10621         6.510000
# 10827         6.580000
# 10829         6.634194
# 10831         6.580000
# 10833         6.580000
# 10835              NaN
# 10837         6.580000
# 11043         6.860000
# 11045         5.140000
# 11047              NaN
# 11049              NaN
# 11051              NaN
# 11053         7.000000

# %%
sales['Product'].unique()
# Out:
# array(['Course Pro Golf and Tee Set', 'Hibernator Self - Inflating Mat',
#        'TrailChef Deluxe Cook Set', 'Deluxe Family Relief Kit',
#        'Course Pro Golf Bag', 'TrailChef Water Bag',
#        'TrailChef Kitchen Kit', 'TrailChef Cook Set',
#        'TrailChef Single Flame', 'TrailChef Double Flame',
#        'Hibernator Camp Cot', 'BugShield Lotion Lite',
#        'Compact Relief Kit', 'Insect Bite Relief', 'Course Pro Umbrella',
#        'Course Pro Gloves', 'Firefly Climbing Lamp',
#        'Firefly Rechargeable Battery', 'Granite Chalk Bag',
#        'TrailChef Canteen', 'TrailChef Cup', 'TrailChef Kettle',
#        'TrailChef Utensils', 'Hibernator Lite', 'Hibernator Extreme',
#        'Hibernator Pad', 'Hibernator Pillow', 'BugShield Natural',
#        'BugShield Spray', 'BugShield Lotion', 'BugShield Extreme',
#        'Calamine Relief', 'Aloe Relief', 'Granite Carabiner',
#        'Granite Belay', 'Granite Pulley', 'Firefly Charger', 'Hibernator'],
#       dtype=object)

# %%
# List all the sales that happened in both the United States and Italy

sales.loc[(sales['Retailer country'] == 'United States') | (sales['Retailer country'] == 'Italy')]
# Out:
#        Year       Product line      Product type                      Product  \
# 0      2004     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 2      2005     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 4      2006     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 23     2004     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 42     2005     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# ...     ...                ...               ...                          ...
# 17813  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17815  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17817  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17819  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17821  2006  Camping Equipment     Sleeping Bags                   Hibernator
#
#       Order method type Retailer country     Revenue  Planned revenue  \
# 0           Sales visit    United States     5819.70          6586.16
# 2           Sales visit    United States    10904.28         11363.52
# 4           Sales visit    United States         NaN              NaN
# 23          Sales visit            Italy        0.00           851.20
# 42          Sales visit            Italy         NaN              NaN
# ...                 ...              ...         ...              ...
# 17813               Web    United States  2858284.19       2982264.13
# 17815           Special    United States         NaN              NaN
# 17817              Mail    United States         NaN              NaN
# 17819            E-mail    United States         NaN              NaN
# 17821               Fax    United States         NaN              NaN
#
#        Product cost  Quantity  Unit cost  Unit price  Gross profit  \
# 0            1733.2     619.0        2.8       10.64       4086.50
# 2            2990.4    1068.0        2.8       10.64       7913.88
# 4               NaN       NaN        NaN         NaN           NaN
# 23            224.0      80.0        2.8       10.64       -224.00
# 42              NaN       NaN        NaN         NaN           NaN
# ...             ...       ...        ...         ...           ...
# 17813     1746746.0   20311.0       86.0      146.83    1111538.19
# 17815           NaN       NaN        NaN         NaN           NaN
# 17817           NaN       NaN        NaN         NaN           NaN
# 17819           NaN       NaN        NaN         NaN           NaN
# 17821           NaN       NaN        NaN         NaN           NaN
#
#        Unit sale price
# 0              5.10500
# 2             10.21000
# 4                  NaN
# 23             0.00000
# 42                 NaN
# ...                ...
# 17813        140.86625
# 17815              NaN
# 17817              NaN
# 17819              NaN
# 17821              NaN
#
# [1712 rows x 14 columns]

# %% [markdown]
# ### <font color='blue'>  DIY-3: Conditional Filtering </font>
#
# Which product had the highest revenue generated through Web Sales?

# %%
webSales = sales.loc[sales['Order method type'] == 'Web']
max_rev = webSales['Revenue'].max()

webSales.loc[webSales['Revenue'] == max_rev, ['Product', 'Revenue']]
# Out:
#                   Product    Revenue
# 10973  Hibernator Extreme  3644349.3

# %% [markdown]
# ### <font color='blue'>  DIY-4: Conditional Filtering with multiple conditions </font>
#
# Come up with a question of your interest that could be answered using
# two or more coniditonal statements to filter your data.

# %%
# What is total revenue from USA sales in 2004?

sales.loc[(sales['Year'] == 2004) & (sales['Retailer country'] == "United States"), 'Revenue'].sum()
# Out:
# 28932195.119999997
